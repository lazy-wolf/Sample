# %% [markdown]
# <a href="https://colab.research.google.com/github/lazy-wolf/Sample/blob/main/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment 4**
#
# ```
# # Authoured by: Wasim Dawood Shaik
# # UNB ID: 3744476
# # Date: 4-12-2023
# ```

# %% [markdown]
# **Import Libraries**

# %%
import tensorflow as tf
from keras.layers import Input, Dense, Reshape, Lambda
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import binary_crossentropy
from keras.models import Model
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import itertools

# %% [markdown]
# **Importing Dataset**

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# **Dataset Info**

# %% [markdown]
# [cifar10 datset link](https://www.tensorflow.org/api_docs/python/tf/keras/datasets/cifar10/load_data)
#
# *https://www.tensorflow.org/api_docs/python/tf/keras/datasets/cifar10/load_data*

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_test.shape
# Out:
# (10000, 32, 32, 3)

# %% [markdown]
# **Data Preprocessing**

# %%
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# %% [markdown]
# **Auto-Encoder (AE) Implementation**

# %% [markdown]
# **Auto-Encoder Model Architecture**

# %%
#Input Layer
input_img = Input(shape=(32, 32, 3))
#Encoding Layer
x = Reshape((32*32*3,))(input_img)
x = Dense(32, activation='relu')(x)
encoded = Dense(8, activation='relu')(x)
#Decoding Layer
x = Dense(32, activation='relu')(encoded)
x = Dense(32*32*3, activation='sigmoid')(x)
decoded = Reshape((32, 32, 3))(x)
#AutoEncoder Model
autoencoder = Model(input_img, decoded)

# %% [markdown]
# **Compiling the Auto-Encoder**

# %%
autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.02), loss='mse')
autoencoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  reshape_2 (Reshape)         (None, 3072)              0
#
#  dense_4 (Dense)             (None, 32)                98336
#
#  dense_5 (Dense)             (None, 8)                 264
#
#  dense_6 (Dense)             (None, 32)                288
#
#  dense_7 (Dense)             (None, 3072)              101376
#
#  reshape_3 (Reshape)         (None, 32, 32, 3)         0
#
# =================================================================
# Total params: 200264 (782.28 KB)
# Trainable params: 200264 (782.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Auto-Encoder Training**

# %%
#Early Stopping with Patience as 5
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
file_path = 'best_model.h5'
#Saving Best Model
model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
#Training the AutoEncoder Model
history = autoencoder.fit(x_train, x_train, validation_data=(x_test, x_test), epochs=25, batch_size=32, callbacks=[early_stop, model_check], verbose=0)
# Out:
# Epoch 1: val_loss improved from inf to 0.06184, saving model to best_model.h5
#
# Epoch 2: val_loss did not improve from 0.06184
#
# Epoch 3: val_loss did not improve from 0.06184
#
# Epoch 4: val_loss did not improve from 0.06184
#
# Epoch 5: val_loss did not improve from 0.06184
#
# Epoch 6: val_loss improved from 0.06184 to 0.06184, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.06184
#
# Epoch 8: val_loss did not improve from 0.06184
#
# Epoch 9: val_loss did not improve from 0.06184
#
# Epoch 10: val_loss did not improve from 0.06184
#
# Epoch 11: val_loss did not improve from 0.06184
# Epoch 11: early stopping

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# **Plot Training History**

# %%
plt.figure(figsize=(12,7))

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %% [markdown]
# **Auto-Encoder Evaluation**

# %%
results=autoencoder.evaluate(x_test, x_test)
print("Test Loss MSE : ", results)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0619
# Test Loss MSE :  0.061867278069257736

# %% [markdown]
# **Auto Encoder Test Dataset Reconstruction**

# %%
x_test_pred = autoencoder.predict(x_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
def calculate_reconstruction_losses(original, reconstructed):
    mse_loss = tf.keras.losses.mean_squared_error(original.flatten(), reconstructed.flatten()).numpy()
    bce_loss = tf.keras.losses.binary_crossentropy(original.flatten(), reconstructed.flatten()).numpy()
    return mse_loss, bce_loss

# %%
calculate_reconstruction_losses(x_test, x_test_pred)
# Out:
# (0.06186727, 0.68954974)

# %% [markdown]
# **Reconstruction Quality : Auto-Encoder**

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 6 + 0.5))  # Adjust the figure size to accommodate three rows
for i in range(n):
    # Display original
    ax = plt.subplot(4, n, i + 1)
    original_img = x_test[i]
    plt.imshow(original_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(4, n, i + 1 + n)
    reconstructed_img = x_test_pred[i]
    plt.imshow(reconstructed_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display difference
    ax = plt.subplot(4, n, i + 1 + n * 2)
    difference = np.abs(original_img - reconstructed_img)
    plt.imshow(difference)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Calculate losses
    mse_loss, bce_loss = calculate_reconstruction_losses(original_img, reconstructed_img)

    # Add captions with losses
    ax = plt.subplot(4, n, i + 1 + n * 3)
    plt.axis('off')
    loss_caption = f"MSE: {mse_loss:.4f}\nBCE: {bce_loss:.4f}"
    plt.text(0.5, 0.5, loss_caption, ha='center', va='center', fontsize=10, transform=ax.transAxes)

plt.show()

# %% [markdown]
# **Hyperparameter Tuning**

# %%
def hyperparameter_tuning_strategy(cofig, x_train, x_test):
  learning_rate, latent_space_dim = config
  possible_combinations = list(itertools.product(learning_rate, latent_space_dim))
  print("*"*25)
  print(f"Possible No.of Combinations : {possible_combinations}")
  print("*"*25)
  hist = []
  for i in range(len(possible_combinations)):
    print("*"*25)
    print(f"Combination : {i+1}")
    print("*"*25)
    l_r, latent_dim = possible_combinations[i]
    #Input Layer
    input_img = Input(shape=(32, 32, 3))
    #Encoding Layer
    x = Reshape((32*32*3,))(input_img)
    x = Dense(32, activation='relu')(x)
    encoded = Dense(latent_dim, activation='relu')(x)
    #Decoding Layer
    x = Dense(32, activation='relu')(encoded)
    x = Dense(32*32*3, activation='sigmoid')(x)
    decoded = Reshape((32, 32, 3))(x)
    #AutoEncoder Model
    autoencoder = Model(input_img, decoded)
    autoencoder.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=l_r), loss='mse')
    #Early Stopping with Patience as 5
    early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    file_path = 'best_model.h5'
    #Saving Best Model
    model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    #Training the AutoEncoder Model
    autoencoder.fit(x_train, x_train, validation_data=(x_test, x_test), epochs=25, batch_size=32, callbacks=[early_stop, model_check], verbose=0)
    test_loss = autoencoder.evaluate(x_test, x_test)
    hist.append(list((l_r, latent_dim, test_loss)))
    print(f"Combination : {i+1} -> {possible_combinations[i]} test_mse : {test_loss}")
    print("*"*25)
    print("*"*25)
  return hist

# %% [markdown]
# **Different HyperParameter Cofigurations for Tuning**

# %%
config = [[0.01, 0.02], [8, 16]]

hist = hyperparameter_tuning_strategy(config, x_train, x_test)
# Out:
# *************************
# Possible No.of Combinations : [(0.01, 8), (0.01, 16), (0.02, 8), (0.02, 16)]
# *************************
# *************************
# Combination : 1
# *************************
#
# Epoch 1: val_loss improved from inf to 0.03741, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.03741 to 0.03725, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 0.03725 to 0.03711, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 0.03711
#
# Epoch 5: val_loss improved from 0.03711 to 0.03707, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 0.03707 to 0.03705, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 0.03705
#
# Epoch 8: val_loss did not improve from 0.03705
#
# Epoch 9: val_loss did not improve from 0.03705
#
# Epoch 10: val_loss did not improve from 0.03705
#
# Epoch 11: val_loss did not improve from 0.03705
# Epoch 11: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0372
# Combination : 1 -> (0.01, 8) test_mse : 0.03715289756655693
# *************************
# *************************
# *************************
# Combination : 2
# *************************
#
# Epoch 1: val_loss improved from inf to 0.03780, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 0.03780 to 0.03699, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 0.03699
#
# Epoch 4: val_loss improved from 0.03699 to 0.03691, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 0.03691
#
# Epoch 6: val_loss did not improve from 0.03691

# %% [markdown]
# **Different HyperParameter Values Test Losses**

# %%
hist = pd.DataFrame(hist, columns=["Learning Rate", "Latent Dimension Space","Test Loss"])
hist = hist.sort_values(by=["Test Loss"], ascending=True)
hist

# %% [markdown]
# **Best Combination after Tuning**

# %%
print("*"*25)
print(f"----Best Combination---- \n Learning Rate = {hist.iloc[0,0]}\n Latent Dimension Space = {hist.iloc[0,1]}\n")
print("*"*25)
print("*"*25)
before_mse = np.round(results, 4)
after_mse = np.round(hist.iloc[0, 2], 4)
print(f'Results Before Tunning:\n Test Loss MSE: {before_mse}\n')
print(f'Results After Tunning:\n Test Loss MSE: {after_mse}\n')
print(f'{np.round((before_mse-after_mse)*100/before_mse)}% Improvement')

# %% [markdown]
# **Best AutoEncoder Model after Tuning**

# %%
l_r, latent_dim = list(hist.iloc[0, :2])

# %%
#Input Layer
input_img = Input(shape=(32, 32, 3))
#Encoding Layer
x = Reshape((32*32*3,))(input_img)
x = Dense(32, activation='relu')(x)
encoded = Dense(latent_dim, activation='relu')(x)
#Decoding Layer
x = Dense(32, activation='relu')(encoded)
x = Dense(32*32*3, activation='sigmoid')(x)
decoded = Reshape((32, 32, 3))(x)

# %%
#AutoEncoder Model
autoencoder_best = Model(input_img, decoded)
autoencoder_best.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=l_r), loss='mse')
autoencoder_best.summary()
# Out:
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  reshape_14 (Reshape)        (None, 3072)              0
#
#  dense_28 (Dense)            (None, 32)                98336
#
#  dense_29 (Dense)            (None, 16)                528
#
#  dense_30 (Dense)            (None, 32)                544
#
#  dense_31 (Dense)            (None, 3072)              101376
#
#  reshape_15 (Reshape)        (None, 32, 32, 3)         0
#
# =================================================================
# Total params: 200784 (784.31 KB)
# Trainable params: 200784 (784.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define the encoder model
encoder_best = Model(input_img, encoded)
encoder_best.summary()

# %%
#Early Stopping with Patience as 5
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
file_path = 'best_model.h5'
#Saving Best Model
model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
#Training the AutoEncoder Model
history = autoencoder_best.fit(x_train, x_train, validation_data=(x_test, x_test), epochs=25, batch_size=32, callbacks=[early_stop, model_check], verbose=0)

# %%
plt.figure(figsize=(12,7))

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
train_loss = autoencoder_best.evaluate(x_train, x_train)
test_loss = autoencoder_best.evaluate(x_test, x_test)

# %%
x_test_pred = autoencoder_best.predict(x_test)
mse_loss, bce_loss = calculate_reconstruction_losses(x_test, x_test_pred)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 6 + 0.5))  # Adjust the figure size to accommodate three rows
for i in range(n):
    # Display original
    ax = plt.subplot(4, n, i + 1)
    original_img = x_test[i]
    plt.imshow(original_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(4, n, i + 1 + n)
    reconstructed_img = x_test_pred[i]
    plt.imshow(reconstructed_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display difference
    ax = plt.subplot(4, n, i + 1 + n * 2)
    difference = np.abs(original_img - reconstructed_img)
    plt.imshow(difference)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Calculate losses
    mse_loss, bce_loss = calculate_reconstruction_losses(original_img, reconstructed_img)

    # Add captions with losses
    ax = plt.subplot(4, n, i + 1 + n * 3)
    plt.axis('off')
    loss_caption = f"MSE: {mse_loss:.4f}\nBCE: {bce_loss:.4f}"
    plt.text(0.5, 0.5, loss_caption, ha='center', va='center', fontsize=10, transform=ax.transAxes)

plt.show()

# %%
# Hyperparameters
batch_size = 32
original_dim = 3072  # 32*32*3
latent_dim = 2
intermediate_dim = 256
epochs = 25
epsilon_std = 1.0

# Encoder network
x = Input(shape=(original_dim,), name='input')
h = Dense(intermediate_dim, activation='relu', name='encoding')(x)
z_mean = Dense(latent_dim, name='mean')(h)
z_log_var = Dense(latent_dim, name='log-variance')(h)

# Sampling function
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# Sample from the latent distribution
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# Decoder network
decoder_h = Dense(intermediate_dim, activation='relu', name='decoder_h')
decoder_mean = Dense(original_dim, activation='sigmoid', name='decoder_mean')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# VAE model
vae = Model(x, x_decoded_mean)

# Loss function: reconstruction loss + KL divergence
reconstruction_loss = binary_crossentropy(x, x_decoded_mean) * original_dim
kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer=Adam())
# vae.summary()

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_train_vae = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_vae = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# %%
#Early Stopping with Patience as 5
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
file_path = 'best_model.h5'
#Saving Best Model
model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
#Training the AutoEncoder Model
history = vae.fit(x_train_vae, x_train_vae, shuffle=True, epochs=epochs, batch_size=batch_size, validation_data=(x_test_vae, x_test_vae), callbacks=[early_stop, model_check], verbose=0)
# Out:
# Epoch 1: val_loss improved from inf to 1962.52222, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 1962.52222 to 1961.10681, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 1961.10681 to 1960.11218, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 1960.11218 to 1959.00854, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 1959.00854 to 1958.45471, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 1958.45471 to 1957.80591, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 1957.80591
#
# Epoch 8: val_loss improved from 1957.80591 to 1956.97168, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 1956.97168 to 1956.87244, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 1956.87244
#
# Epoch 11: val_loss improved from 1956.87244 to 1956.15820, saving model to best_model.h5
#
# Epoch 12: val_loss improved from 1956.15820 to 1955.94592, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 1955.94592
#
# Epoch 14: val_loss improved from 1955.94592 to 1954.63159, saving model to best_model.h5
#
# Epoch 15: val_loss did not improve from 1954.63159
#
# Epoch 16: val_loss did not improve from 1954.63159
#
# Epoch 17: val_loss improved from 1954.63159 to 1954.27673, saving model to best_model.h5
#
# Epoch 18: val_loss did not improve from 1954.27673
#
# Epoch 19: val_loss did not improve from 1954.27673
#
# Epoch 20: val_loss improved from 1954.27673 to 1953.85059, saving model to best_model.h5
#
# Epoch 21: val_loss did not improve from 1953.85059
#
# Epoch 22: val_loss did not improve from 1953.85059
#
# Epoch 23: val_loss improved from 1953.85059 to 1953.30334, saving model to best_model.h5
#
# Epoch 24: val_loss did not improve from 1953.30334
#
# Epoch 25: val_loss improved from 1953.30334 to 1952.68213, saving model to best_model.h5

# %%
results = vae.evaluate(x_test_vae, x_test_vae)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 1952.6909

# %%
x_test_pred = vae.predict(x_test_vae)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
mse_loss, bce_loss = calculate_reconstruction_losses(x_test_vae, x_test_pred)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 6 + 0.5))  # Adjust the figure size to accommodate three rows
for i in range(n):
    # Display original
    ax = plt.subplot(4, n, i + 1)
    original_img = x_test_vae[i].reshape(32,32,3)
    plt.imshow(original_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(4, n, i + 1 + n)
    reconstructed_img = x_test_pred[i].reshape(32,32,3)
    plt.imshow(reconstructed_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display difference
    ax = plt.subplot(4, n, i + 1 + n * 2)
    difference = np.abs(original_img - reconstructed_img)
    plt.imshow(difference)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Calculate losses
    mse_loss, bce_loss = calculate_reconstruction_losses(original_img, reconstructed_img)

    # Add captions with losses
    ax = plt.subplot(4, n, i + 1 + n * 3)
    plt.axis('off')
    loss_caption = f"MSE: {mse_loss:.4f}\nBCE: {bce_loss:.4f}"
    plt.text(0.5, 0.5, loss_caption, ha='center', va='center', fontsize=10, transform=ax.transAxes)

plt.show()

# %%
def hyperparameter_tuning_strategy(cofig, x_train, x_test):
  intermediate_dim, latent_dim = config
  possible_combinations = list(itertools.product(intermediate_dim, latent_dim))
  print("*"*25)
  print(f"Possible No.of Combinations : {possible_combinations}")
  print("*"*25)
  hist = []
  for i in range(len(possible_combinations)):
    print("*"*25)
    print(f"Combination : {i+1}")
    print("*"*25)
    intermediate_dim, latent_dim = possible_combinations[i]
    # Hyperparameters
    batch_size = 32
    original_dim = 3072  # 32*32*3
    epochs = 25
    epsilon_std = 1.0

    # Encoder network
    x = Input(shape=(original_dim,), name='input')
    h = Dense(intermediate_dim, activation='relu', name='encoding')(x)
    z_mean = Dense(latent_dim, name='mean')(h)
    z_log_var = Dense(latent_dim, name='log-variance')(h)

    # Sampling function
    def sampling(args):
        z_mean, z_log_var = args
        epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=epsilon_std)
        return z_mean + K.exp(z_log_var / 2) * epsilon

    # Sample from the latent distribution
    z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

    # Decoder network
    decoder_h = Dense(intermediate_dim, activation='relu', name='decoder_h')
    decoder_mean = Dense(original_dim, activation='sigmoid', name='decoder_mean')
    h_decoded = decoder_h(z)
    x_decoded_mean = decoder_mean(h_decoded)

    # VAE model
    vae = Model(x, x_decoded_mean)

    # Loss function: reconstruction loss + KL divergence
    reconstruction_loss = binary_crossentropy(x, x_decoded_mean) * original_dim
    kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    vae_loss = K.mean(reconstruction_loss + kl_loss)
    vae.add_loss(vae_loss)
    vae.compile(optimizer=Adam())
    #Early Stopping with Patience as 5
    early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
    file_path = 'best_model.h5'
    #Saving Best Model
    model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
    #Training the AutoEncoder Model
    x_train_vae = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
    x_test_vae = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
    history = vae.fit(x_train_vae, x_train_vae, shuffle=True, epochs=epochs, batch_size=batch_size, validation_data=(x_test_vae, x_test_vae), callbacks=[early_stop, model_check], verbose=0)
    test_loss = vae.evaluate(x_test_vae, x_test_vae)
    hist.append(list((intermediate_dim, latent_dim, test_loss)))
    print(f"Combination : {i+1} -> {possible_combinations[i]}  test_mse : {test_loss}")
    print("*"*25)
    print("*"*25)
  return hist

# %%
config = [[128, 256], [2, 4]]

hist = hyperparameter_tuning_strategy(config, x_train, x_test)
# Out:
# *************************
# Possible No.of Combinations : [(128, 2), (128, 4), (256, 2), (256, 4)]
# *************************
# *************************
# Combination : 1
# *************************
#
# Epoch 1: val_loss improved from inf to 1965.11877, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 1965.11877 to 1961.11743, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 1961.11743 to 1960.14221, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 1960.14221 to 1959.43628, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 1959.43628
#
# Epoch 6: val_loss improved from 1959.43628 to 1958.30371, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 1958.30371
#
# Epoch 8: val_loss improved from 1958.30371 to 1957.87195, saving model to best_model.h5
#
# Epoch 9: val_loss did not improve from 1957.87195
#
# Epoch 10: val_loss improved from 1957.87195 to 1957.55493, saving model to best_model.h5
#
# Epoch 11: val_loss improved from 1957.55493 to 1956.75500, saving model to best_model.h5
#
# Epoch 12: val_loss improved from 1956.75500 to 1955.72327, saving model to best_model.h5
#
# Epoch 13: val_loss improved from 1955.72327 to 1955.44495, saving model to best_model.h5
#
# Epoch 14: val_loss did not improve from 1955.44495
#
# Epoch 15: val_loss did not improve from 1955.44495
#
# Epoch 16: val_loss improved from 1955.44495 to 1954.49902, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 1954.49902
#
# Epoch 18: val_loss improved from 1954.49902 to 1953.91528, saving model to best_model.h5
#
# Epoch 19: val_loss did not improve from 1953.91528
#
# Epoch 20: val_loss improved from 1953.91528 to 1953.61060, saving model to best_model.h5
#
# Epoch 21: val_loss did not improve from 1953.61060
#
# Epoch 22: val_loss did not improve from 1953.61060
#
# Epoch 23: val_loss improved from 1953.61060 to 1953.22070, saving model to best_model.h5
#
# Epoch 24: val_loss did not improve from 1953.22070
#
# Epoch 25: val_loss did not improve from 1953.22070
# 313/313 [==============================] - 1s 3ms/step - loss: 1953.8693
# Combination : 1 -> (128, 2)  test_mse : 1953.8692626953125
# *************************
# *************************
# *************************
# Combination : 2
# *************************
#
# Epoch 1: val_loss improved from inf to 1924.89417, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 1924.89417 to 1922.27197, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 1922.27197
#
# Epoch 4: val_loss improved from 1922.27197 to 1918.35168, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 1918.35168 to 1917.01880, saving model to best_model.h5
#
# Epoch 6: val_loss did not improve from 1917.01880
#
# Epoch 7: val_loss did not improve from 1917.01880
#
# Epoch 8: val_loss improved from 1917.01880 to 1915.71204, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 1915.71204 to 1915.28772, saving model to best_model.h5
#
# Epoch 10: val_loss did not improve from 1915.28772
#
# Epoch 11: val_loss improved from 1915.28772 to 1914.77881, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 1914.77881
#
# Epoch 13: val_loss improved from 1914.77881 to 1914.02820, saving model to best_model.h5
#
# Epoch 14: val_loss improved from 1914.02820 to 1913.89099, saving model to best_model.h5
#
# Epoch 15: val_loss improved from 1913.89099 to 1913.68506, saving model to best_model.h5
#
# Epoch 16: val_loss improved from 1913.68506 to 1913.27271, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 1913.27271
#
# Epoch 18: val_loss improved from 1913.27271 to 1913.25305, saving model to best_model.h5
#
# Epoch 19: val_loss did not improve from 1913.25305
#
# Epoch 20: val_loss improved from 1913.25305 to 1912.61145, saving model to best_model.h5
#
# Epoch 21: val_loss did not improve from 1912.61145
#
# Epoch 22: val_loss did not improve from 1912.61145
#
# Epoch 23: val_loss did not improve from 1912.61145
#
# Epoch 24: val_loss did not improve from 1912.61145
#
# Epoch 25: val_loss did not improve from 1912.61145
# Epoch 25: early stopping
# 313/313 [==============================] - 1s 3ms/step - loss: 1913.0345
# Combination : 2 -> (128, 4)  test_mse : 1913.0345458984375
# *************************
# *************************
# *************************
# Combination : 3
# *************************
#
# Epoch 1: val_loss improved from inf to 1967.06689, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 1967.06689 to 1964.36682, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 1964.36682 to 1960.29736, saving model to best_model.h5
#
# Epoch 4: val_loss improved from 1960.29736 to 1959.91748, saving model to best_model.h5
#
# Epoch 5: val_loss did not improve from 1959.91748
#
# Epoch 6: val_loss improved from 1959.91748 to 1957.46106, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 1957.46106
#
# Epoch 8: val_loss improved from 1957.46106 to 1956.74438, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 1956.74438 to 1956.24036, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 1956.24036 to 1956.19714, saving model to best_model.h5
#
# Epoch 11: val_loss improved from 1956.19714 to 1955.80835, saving model to best_model.h5
#
# Epoch 12: val_loss did not improve from 1955.80835
#
# Epoch 13: val_loss improved from 1955.80835 to 1955.43945, saving model to best_model.h5
#
# Epoch 14: val_loss improved from 1955.43945 to 1954.60681, saving model to best_model.h5
#
# Epoch 15: val_loss improved from 1954.60681 to 1954.40710, saving model to best_model.h5
#
# Epoch 16: val_loss did not improve from 1954.40710
#
# Epoch 17: val_loss improved from 1954.40710 to 1953.56567, saving model to best_model.h5
#
# Epoch 18: val_loss did not improve from 1953.56567
#
# Epoch 19: val_loss did not improve from 1953.56567
#
# Epoch 20: val_loss improved from 1953.56567 to 1951.83191, saving model to best_model.h5
#
# Epoch 21: val_loss improved from 1951.83191 to 1951.43884, saving model to best_model.h5
#
# Epoch 22: val_loss did not improve from 1951.43884
#
# Epoch 23: val_loss improved from 1951.43884 to 1950.44971, saving model to best_model.h5
#
# Epoch 24: val_loss did not improve from 1950.44971
#
# Epoch 25: val_loss improved from 1950.44971 to 1949.86279, saving model to best_model.h5
# 313/313 [==============================] - 1s 2ms/step - loss: 1949.7917
# Combination : 3 -> (256, 2)  test_mse : 1949.791748046875
# *************************
# *************************
# *************************
# Combination : 4
# *************************
#
# Epoch 1: val_loss improved from inf to 1925.09363, saving model to best_model.h5
#
# Epoch 2: val_loss improved from 1925.09363 to 1919.72607, saving model to best_model.h5
#
# Epoch 3: val_loss did not improve from 1919.72607
#
# Epoch 4: val_loss improved from 1919.72607 to 1916.36536, saving model to best_model.h5
#
# Epoch 5: val_loss improved from 1916.36536 to 1915.38562, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 1915.38562 to 1914.30127, saving model to best_model.h5
#
# Epoch 7: val_loss did not improve from 1914.30127
#
# Epoch 8: val_loss improved from 1914.30127 to 1914.14819, saving model to best_model.h5
#
# Epoch 9: val_loss improved from 1914.14819 to 1913.84045, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 1913.84045 to 1913.24158, saving model to best_model.h5
#
# Epoch 11: val_loss improved from 1913.24158 to 1913.01880, saving model to best_model.h5
#
# Epoch 12: val_loss improved from 1913.01880 to 1912.50684, saving model to best_model.h5
#
# Epoch 13: val_loss did not improve from 1912.50684
#
# Epoch 14: val_loss improved from 1912.50684 to 1912.22461, saving model to best_model.h5
#
# Epoch 15: val_loss did not improve from 1912.22461
#
# Epoch 16: val_loss did not improve from 1912.22461
#
# Epoch 17: val_loss improved from 1912.22461 to 1912.01294, saving model to best_model.h5
#
# Epoch 18: val_loss did not improve from 1912.01294
#
# Epoch 19: val_loss did not improve from 1912.01294
#
# Epoch 20: val_loss did not improve from 1912.01294
#
# Epoch 21: val_loss did not improve from 1912.01294
#
# Epoch 22: val_loss did not improve from 1912.01294
# Epoch 22: early stopping
# 313/313 [==============================] - 1s 4ms/step - loss: 1912.4749
# Combination : 4 -> (256, 4)  test_mse : 1912.474853515625
# *************************
# *************************

# %%
hist = pd.DataFrame(hist, columns=["Intermediate Dimension", "Latent Dimension Space", "Test Loss"])
hist = hist.sort_values(by=["Test Loss"], ascending=True)
hist
# Out:
#    Intermediate Dimension  Latent Dimension Space    Test Loss
# 3                     256                       4  1912.474854
# 1                     128                       4  1913.034546
# 2                     256                       2  1949.791748
# 0                     128                       2  1953.869263

# %%
print("*"*25)
print(f"----Best Combination---- \n Learning Rate = {hist.iloc[0,0]}\n Latent Dimension Space = {hist.iloc[0,1]}\n")
print("*"*25)
print("*"*25)
before_mse = np.round(results, 4)
after_mse = np.round(hist.iloc[0, 2], 4)
print(f'Results Before Tunning:\n Test Loss MSE: {before_mse}\n')
print(f'Results After Tunning:\n Test Loss MSE: {after_mse}\n')
print(f'{np.round((before_mse-after_mse)*100/before_mse)}% Improvement')
# Out:
# *************************
# ----Best Combination----
#  Learning Rate = 256
#  Latent Dimension Space = 4
#
# *************************
# *************************
# Results Before Tunning:
#  Test Loss MSE: 1952.6909
#
# Results After Tunning:
#  Test Loss MSE: 1912.4749
#
# 2.0% Improvement

# %%
list(hist.iloc[0, :2])
# Out:
# [256.0, 4.0]

# %%
intermediate_dim, latent_dim = list(hist.iloc[0, :2])

# %%
# Hyperparameters
batch_size = 32
original_dim = 3072  # 32*32*3
latent_dim = int(latent_dim)
intermediate_dim = int(intermediate_dim)
epochs = 25
epsilon_std = 1.0

# Encoder network
x = Input(shape=(original_dim,), name='input')
h = Dense(intermediate_dim, activation='relu', name='encoding')(x)
z_mean = Dense(latent_dim, name='mean')(h)
z_log_var = Dense(latent_dim, name='log-variance')(h)

# Sampling function
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0., stddev=epsilon_std)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# Sample from the latent distribution
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_var])

# Decoder network
decoder_h = Dense(intermediate_dim, activation='relu', name='decoder_h')
decoder_mean = Dense(original_dim, activation='sigmoid', name='decoder_mean')
h_decoded = decoder_h(z)
x_decoded_mean = decoder_mean(h_decoded)

# VAE model
vae = Model(x, x_decoded_mean)

# Loss function: reconstruction loss + KL divergence
reconstruction_loss = binary_crossentropy(x, x_decoded_mean) * original_dim
kl_loss = -0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
vae_loss = K.mean(reconstruction_loss + kl_loss)
vae.add_loss(vae_loss)
vae.compile(optimizer=Adam())
# vae.summary()

# %%
#Early Stopping with Patience as 5
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
file_path = 'best_model.h5'
#Saving Best Model
model_check = ModelCheckpoint(file_path, monitor='val_loss', mode='min', verbose=1, save_best_only=True)
#Training the AutoEncoder Model
x_train_vae = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test_vae = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
history = vae.fit(x_train_vae, x_train_vae, shuffle=True, epochs=epochs, batch_size=batch_size, validation_data=(x_test_vae, x_test_vae), callbacks=[early_stop, model_check], verbose=0)
# Out:
# Epoch 1: val_loss improved from inf to 1924.23169, saving model to best_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 1924.23169 to 1920.18909, saving model to best_model.h5
#
# Epoch 3: val_loss improved from 1920.18909 to 1918.52380, saving model to best_model.h5
#
# Epoch 4: val_loss did not improve from 1918.52380
#
# Epoch 5: val_loss improved from 1918.52380 to 1915.50818, saving model to best_model.h5
#
# Epoch 6: val_loss improved from 1915.50818 to 1914.85046, saving model to best_model.h5
#
# Epoch 7: val_loss improved from 1914.85046 to 1914.68506, saving model to best_model.h5
#
# Epoch 8: val_loss did not improve from 1914.68506
#
# Epoch 9: val_loss improved from 1914.68506 to 1914.53430, saving model to best_model.h5
#
# Epoch 10: val_loss improved from 1914.53430 to 1913.73022, saving model to best_model.h5
#
# Epoch 11: val_loss did not improve from 1913.73022
#
# Epoch 12: val_loss improved from 1913.73022 to 1913.21887, saving model to best_model.h5
#
# Epoch 13: val_loss improved from 1913.21887 to 1912.58826, saving model to best_model.h5
#
# Epoch 14: val_loss did not improve from 1912.58826
#
# Epoch 15: val_loss improved from 1912.58826 to 1912.53455, saving model to best_model.h5
#
# Epoch 16: val_loss improved from 1912.53455 to 1911.77539, saving model to best_model.h5
#
# Epoch 17: val_loss did not improve from 1911.77539
#
# Epoch 18: val_loss did not improve from 1911.77539
#
# Epoch 19: val_loss did not improve from 1911.77539
#
# Epoch 20: val_loss improved from 1911.77539 to 1911.30725, saving model to best_model.h5
#
# Epoch 21: val_loss did not improve from 1911.30725
#
# Epoch 22: val_loss did not improve from 1911.30725
#
# Epoch 23: val_loss improved from 1911.30725 to 1911.27051, saving model to best_model.h5
#
# Epoch 24: val_loss improved from 1911.27051 to 1911.16016, saving model to best_model.h5
#
# Epoch 25: val_loss did not improve from 1911.16016

# %%
plt.figure(figsize=(12,7))

plt.plot(history.epoch, history.history['loss'], label="loss")
plt.plot(history.epoch, history.history['val_loss'], label="val_loss")

plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.grid(alpha=0.3)
plt.legend()

plt.show()

# %%
test_loss = vae.evaluate(x_test_vae, x_test_vae)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1911.9677

# %%
x_test_pred = vae.predict(x_test_vae)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
mse_loss, bce_loss = calculate_reconstruction_losses(x_test_vae, x_test_pred)

# %%
n = 10  # How many digits we will display
plt.figure(figsize=(20, 6 + 0.5))  # Adjust the figure size to accommodate three rows
for i in range(n):
    # Display original
    ax = plt.subplot(4, n, i + 1)
    original_img = x_test_vae[i].reshape(32,32,3)
    plt.imshow(original_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(4, n, i + 1 + n)
    reconstructed_img = x_test_pred[i].reshape(32,32,3)
    plt.imshow(reconstructed_img)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display difference
    ax = plt.subplot(4, n, i + 1 + n * 2)
    difference = np.abs(original_img - reconstructed_img)
    plt.imshow(difference)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Calculate losses
    mse_loss, bce_loss = calculate_reconstruction_losses(original_img, reconstructed_img)

    # Add captions with losses
    ax = plt.subplot(4, n, i + 1 + n * 3)
    plt.axis('off')
    loss_caption = f"MSE: {mse_loss:.4f}\nBCE: {bce_loss:.4f}"
    plt.text(0.5, 0.5, loss_caption, ha='center', va='center', fontsize=10, transform=ax.transAxes)

plt.show()

# %%
# Build a model to project inputs on the latent space
encoder = Model(x, z_mean)

# %%
# Display a 2D plot of the digit classes in the latent space
x_test_encoded = encoder.predict(x_test_vae, batch_size=batch_size)
import matplotlib.pyplot as plt
plt.figure(figsize=(6, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test)
plt.colorbar()
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
